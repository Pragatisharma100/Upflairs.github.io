# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('air_pollution_data.csv')

# %%
df.head()
# Out:
#         city        date  aqi       co     no    no2      o3    so2   pm2_5  \
# 0  Ahmedabad  30-11-2020    5   520.71   2.38  16.28  130.18  47.68   65.96
# 1  Ahmedabad  01-12-2020    5  1682.28   7.71  54.84    0.73  21.70  120.95
# 2  Ahmedabad  02-12-2020    5  1815.80  16.54  49.35    0.17  23.84  133.47
# 3  Ahmedabad  03-12-2020    5  2296.45  41.57  40.10    0.00  35.76  150.37
# 4  Ahmedabad  04-12-2020    5  2189.64  23.92  58.95    0.02  28.13  160.79
#
#      pm10    nh3
# 0   72.13   8.36
# 1  154.53  27.36
# 2  172.63  28.12
# 3  202.15  36.48
# 4  205.80  40.53

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23504 entries, 0 to 23503
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    23504 non-null  object
#  1   date    23504 non-null  object
#  2   aqi     23504 non-null  int64
#  3   co      23504 non-null  float64
#  4   no      23504 non-null  float64
#  5   no2     23504 non-null  float64
#  6   o3      23504 non-null  float64
#  7   so2     23504 non-null  float64
#  8   pm2_5   23504 non-null  float64
#  9   pm10    23504 non-null  float64
#  10  nh3     23504 non-null  float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 2.0+ MB

# %%
# checking for duplicates
df.duplicated().sum() # no duplicates found
# Out:
# np.int64(0)

# %%
#Eradication of duplicate values 
df.drop_duplicates(inplace=True)

# %%
#checking for any null values 
df.isnull().sum() #no null values
# Out:
# city     0
# date     0
# aqi      0
# co       0
# no       0
# no2      0
# o3       0
# so2      0
# pm2_5    0
# pm10     0
# nh3      0
# dtype: int64

# %%
df.dropna(inplace=True,axis=0)

# %%
df
# Out:
#                 city        date  aqi       co     no    no2      o3    so2  \
# 0          Ahmedabad  30-11-2020    5   520.71   2.38  16.28  130.18  47.68
# 1          Ahmedabad  01-12-2020    5  1682.28   7.71  54.84    0.73  21.70
# 2          Ahmedabad  02-12-2020    5  1815.80  16.54  49.35    0.17  23.84
# 3          Ahmedabad  03-12-2020    5  2296.45  41.57  40.10    0.00  35.76
# 4          Ahmedabad  04-12-2020    5  2189.64  23.92  58.95    0.02  28.13
# ...              ...         ...  ...      ...    ...    ...     ...    ...
# 23499  Visakhapatnam  21-05-2023    3   353.81   0.00   2.08  100.14   4.11
# 23500  Visakhapatnam  22-05-2023    3   380.52   0.00   3.77   82.97   5.07
# 23501  Visakhapatnam  23-05-2023    3   390.53   0.00   4.28   80.11   5.19
# 23502  Visakhapatnam  24-05-2023    3   300.41   0.00   1.36   95.84   2.21
# 23503  Visakhapatnam  25-05-2023    4   427.25   0.00   6.00   88.69  10.73
#
#         pm2_5    pm10    nh3
# ...

# %%
df['city'].value_counts()
# Out:
# city
# Ahmedabad             904
# Aizawl                904
# Amaravati             904
# Amritsar              904
# Bengaluru             904
# Bhopal                904
# Brajrajnagar          904
# Chandigarh            904
# Chennai               904
# Coimbatore            904
# Delhi                 904
# Ernakulam             904
# Gurugram              904
# Guwahati              904
# Hyderabad             904
# Jaipur                904
# Jorapokhar            904
# Kochi                 904
# Kolkata               904
# Lucknow               904
# Mumbai                904
# Patna                 904
# Shillong              904
# Talcher               904
# Thiruvananthapuram    904
# Visakhapatnam         904
# Name: count, dtype: int64

# %%
Delhi=df[df['city']=='Delhi']

# %%
Delhi #AQI in Delhi city
# Out:
#        city        date  aqi       co     no    no2      o3    so2   pm2_5  \
# 9040  Delhi  30-11-2020    5   988.01   1.24  13.71  205.99  34.33  133.73
# 9041  Delhi  01-12-2020    5  3150.94  30.40  66.49    0.00  14.90  299.99
# 9042  Delhi  02-12-2020    5  3524.78  18.11  71.97    0.05  12.16  455.67
# 9043  Delhi  03-12-2020    5  1922.61   0.03  52.78   27.54  11.09  208.94
# 9044  Delhi  04-12-2020    5  3738.40   0.64  78.14   11.00  16.69  595.27
# ...     ...         ...  ...      ...    ...    ...     ...    ...     ...
# 9939  Delhi  21-05-2023    5  3070.83  12.85  81.57    0.08  69.62  172.37
# 9940  Delhi  22-05-2023    5  1575.47   0.32  50.04    9.92  31.95   81.03
# 9941  Delhi  23-05-2023    4  1068.12   0.00  34.62   37.19  23.60   65.72
# 9942  Delhi  24-05-2023    4  1001.36   0.01  37.01   27.18  24.08   53.07
# 9943  Delhi  25-05-2023    5  1161.58   0.00  24.33   62.94  28.85   82.46
#
#         pm10    nh3
# 9040  156.15   9.88
# 9041  428.61  16.09
# ...

# %%
Delhi.reset_index(drop=True,inplace=True)

# %%
Delhi
# Out:
#       city        date  aqi       co     no    no2      o3    so2   pm2_5  \
# 0    Delhi  30-11-2020    5   988.01   1.24  13.71  205.99  34.33  133.73
# 1    Delhi  01-12-2020    5  3150.94  30.40  66.49    0.00  14.90  299.99
# 2    Delhi  02-12-2020    5  3524.78  18.11  71.97    0.05  12.16  455.67
# 3    Delhi  03-12-2020    5  1922.61   0.03  52.78   27.54  11.09  208.94
# 4    Delhi  04-12-2020    5  3738.40   0.64  78.14   11.00  16.69  595.27
# ..     ...         ...  ...      ...    ...    ...     ...    ...     ...
# 899  Delhi  21-05-2023    5  3070.83  12.85  81.57    0.08  69.62  172.37
# 900  Delhi  22-05-2023    5  1575.47   0.32  50.04    9.92  31.95   81.03
# 901  Delhi  23-05-2023    4  1068.12   0.00  34.62   37.19  23.60   65.72
# 902  Delhi  24-05-2023    4  1001.36   0.01  37.01   27.18  24.08   53.07
# 903  Delhi  25-05-2023    5  1161.58   0.00  24.33   62.94  28.85   82.46
#
#        pm10    nh3
# 0    156.15   9.88
# 1    428.61  16.09
# ...

# %%
Delhi_2020=Delhi.loc[0:31] #AQI for Delhi in 2020

# %%
Delhi_2021=Delhi.loc[32:396] #AQI for Delhi in 2021

# %%
Delhi_2022=Delhi.loc[396:759] #AQI for Delhi in 2022

# %%
Delhi_2023=Delhi.loc[759:] #AQI for Delhi in 2023

# %% [markdown]
# For 2020

# %%
x=list(Delhi_2020['aqi'].value_counts().values)
label=list(Delhi_2020['aqi'].value_counts().keys())
plt.pie(x,labels=label,autopct='%1.2f%%',wedgeprops={'ec':'k'},shadow=True)
plt.show()

# %% [markdown]
# For 2021

# %%
x=list(Delhi_2021['aqi'].value_counts().values)
label=list(Delhi_2021['aqi'].value_counts().keys())
plt.pie(x,labels=label,autopct='%1.2f%%',wedgeprops={'ec':'k'},shadow=True)
plt.show()

# %% [markdown]
# For 2022

# %%
x=list(Delhi_2022['aqi'].value_counts().values)
label=list(Delhi_2022['aqi'].value_counts().keys())
plt.pie(x,labels=label,autopct='%1.2f%%',wedgeprops={'ec':'k'},shadow=True)
plt.show()

# %% [markdown]
# For 2023

# %%
x=list(Delhi_2023['aqi'].value_counts().values)
label=list(Delhi_2023['aqi'].value_counts().keys())
plt.pie(x,labels=label,autopct='%1.2f%%',wedgeprops={'ec':'k'},shadow=True)
plt.show()

# %%
city=df.groupby('city')

# %%
Jaipur=city.get_group('Jaipur')

# %%
sns.catplot(x='city',y='aqi',data=df,kind='bar',height=8.27,aspect=25.7/14.27,color='yellow',ec='k')
plt.xticks(rotation=22)
plt.xlabel('CITY')
plt.ylabel('AQI')
# Out:
# Text(29.396523377350825, 0.5, 'AQI')

# %%
df.head()
# Out:
#         city        date  aqi       co     no    no2      o3    so2   pm2_5  \
# 0  Ahmedabad  30-11-2020    5   520.71   2.38  16.28  130.18  47.68   65.96
# 1  Ahmedabad  01-12-2020    5  1682.28   7.71  54.84    0.73  21.70  120.95
# 2  Ahmedabad  02-12-2020    5  1815.80  16.54  49.35    0.17  23.84  133.47
# 3  Ahmedabad  03-12-2020    5  2296.45  41.57  40.10    0.00  35.76  150.37
# 4  Ahmedabad  04-12-2020    5  2189.64  23.92  58.95    0.02  28.13  160.79
#
#      pm10    nh3
# 0   72.13   8.36
# 1  154.53  27.36
# 2  172.63  28.12
# 3  202.15  36.48
# 4  205.80  40.53

# %%
sns.catplot(x='aqi',y='o3',data=df,kind='bar',color='green')

# %%
sns.relplot(x='pm2_5',y='pm10',data=df,hue='co',style='aqi')

# %%
sns.catplot(x='city',y='co',data=df,kind='box',height=8.27,aspect=25.7/14.27,color='turquoise')
plt.xticks(rotation=22)
plt.show()

# %%
df['city'].value_counts().keys()
# Out:
# Index(['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru', 'Bhopal',
#        'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore', 'Delhi',
#        'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad', 'Jaipur',
#        'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai', 'Patna',
#        'Shillong', 'Talcher', 'Thiruvananthapuram', 'Visakhapatnam'],
#       dtype='object', name='city')

# %%
city_list=['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru', 'Bhopal',
       'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore', 'Delhi',
       'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad', 'Jaipur',
       'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai', 'Patna',
       'Shillong', 'Talcher', 'Thiruvananthapuram', 'Visakhapatnam']
dt={}
for i in range(0,len(city_list)):
    dt[city_list[i]]=i+1

# %%
df['city']=df['city'].map(dt)

# %%
dt
# Out:
# {'Ahmedabad': 1,
#  'Aizawl': 2,
#  'Amaravati': 3,
#  'Amritsar': 4,
#  'Bengaluru': 5,
#  'Bhopal': 6,
#  'Brajrajnagar': 7,
#  'Chandigarh': 8,
#  'Chennai': 9,
#  'Coimbatore': 10,
#  'Delhi': 11,
#  'Ernakulam': 12,
#  'Gurugram': 13,
#  'Guwahati': 14,
#  'Hyderabad': 15,
#  'Jaipur': 16,
#  'Jorapokhar': 17,
#  'Kochi': 18,
#  'Kolkata': 19,
#  'Lucknow': 20,
#  'Mumbai': 21,
#  'Patna': 22,
#  'Shillong': 23,
#  'Talcher': 24,
#  'Thiruvananthapuram': 25,
#  'Visakhapatnam': 26}

# %%
ls=list(df['date'])
df_date={}
for i in range(len(ls)):
    if ls[i].endswith('2020'):
         df_date[ls[i]]=2020
    elif ls[i].endswith('2021'):
         df_date[ls[i]]=2021
    elif ls[i].endswith('2022'):
         df_date[ls[i]]=2022
    elif ls[i].endswith('2023'):
         df_date[ls[i]]=2023

# %%
df['date']=df['date'].map(df_date)

# %%
df.columns=['city', 'year', 'aqi', 'co', 'no', 'no2', 'o3', 'so2', 'pm2_5', 'pm10',
       'nh3']

# %%
df
# Out:
#        city  year  aqi       co     no    no2      o3    so2   pm2_5    pm10  \
# 0         1  2020    5   520.71   2.38  16.28  130.18  47.68   65.96   72.13
# 1         1  2020    5  1682.28   7.71  54.84    0.73  21.70  120.95  154.53
# 2         1  2020    5  1815.80  16.54  49.35    0.17  23.84  133.47  172.63
# 3         1  2020    5  2296.45  41.57  40.10    0.00  35.76  150.37  202.15
# 4         1  2020    5  2189.64  23.92  58.95    0.02  28.13  160.79  205.80
# ...     ...   ...  ...      ...    ...    ...     ...    ...     ...     ...
# 23499    26  2023    3   353.81   0.00   2.08  100.14   4.11   37.53   47.09
# 23500    26  2023    3   380.52   0.00   3.77   82.97   5.07   32.17   43.44
# 23501    26  2023    3   390.53   0.00   4.28   80.11   5.19   36.01   48.06
# 23502    26  2023    3   300.41   0.00   1.36   95.84   2.21   30.17   48.89
# 23503    26  2023    4   427.25   0.00   6.00   88.69  10.73   52.36   61.41
#
#          nh3
# 0       8.36
# 1      27.36
# ...

# %%
x=df.drop('aqi',axis=1)
y=df[['aqi']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dfc=DecisionTreeClassifier()

# %%
dfc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print('Training score:',dfc.score(x_train,y_train)*100)
print('Testing score:',dfc.score(x_test,y_test)*100)
# Out:
# Training score: 100.0
# Testing score: 99.21293341842161

# %%
prediction=dfc.predict(x_test)

# %%
y_test['prediction']=prediction

# %%
y_test
# Out:
#        aqi  prediction
# 17905    5           5
# 17445    4           4
# 17314    5           5
# 13175    5           5
# 2842     5           5
# ...    ...         ...
# 10480    1           1
# 16745    5           5
# 6775     5           5
# 2290     3           3
# 3033     5           5
#
# [4701 rows x 2 columns]

# %%
import joblib

# %%
joblib.dump(dfc,'decisisiontreeclassifier.lb')
# Out:
# ['decisisiontreeclassifier.lb']
