# %% [markdown]
# <H1>                              AQI QUALITY</H1>

# %% [markdown]
# IMPORTING THE DATA FILE

# %%
# Numpy
import numpy as np
#Pandas
import pandas as pd
#matplotlib
import matplotlib.pyplot as plt
# Seaborn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# READING THE CSV FILE

# %%
df=pd.read_csv('air_pollution_data.csv')

# %% [markdown]
# FETCHING THE DF

# %%
df
# Out:
#                 city        date  aqi       co     no    no2      o3    so2  \
# 0          Ahmedabad  30-11-2020    5   520.71   2.38  16.28  130.18  47.68
# 1          Ahmedabad  01-12-2020    5  1682.28   7.71  54.84    0.73  21.70
# 2          Ahmedabad  02-12-2020    5  1815.80  16.54  49.35    0.17  23.84
# 3          Ahmedabad  03-12-2020    5  2296.45  41.57  40.10    0.00  35.76
# 4          Ahmedabad  04-12-2020    5  2189.64  23.92  58.95    0.02  28.13
# ...              ...         ...  ...      ...    ...    ...     ...    ...
# 23499  Visakhapatnam  21-05-2023    3   353.81   0.00   2.08  100.14   4.11
# 23500  Visakhapatnam  22-05-2023    3   380.52   0.00   3.77   82.97   5.07
# 23501  Visakhapatnam  23-05-2023    3   390.53   0.00   4.28   80.11   5.19
# 23502  Visakhapatnam  24-05-2023    3   300.41   0.00   1.36   95.84   2.21
# 23503  Visakhapatnam  25-05-2023    4   427.25   0.00   6.00   88.69  10.73
#
#         pm2_5    pm10    nh3
# ...

# %% [markdown]
# ALL INFORMATION OF DF

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23504 entries, 0 to 23503
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    23504 non-null  object
#  1   date    23504 non-null  object
#  2   aqi     23504 non-null  int64
#  3   co      23504 non-null  float64
#  4   no      23504 non-null  float64
#  5   no2     23504 non-null  float64
#  6   o3      23504 non-null  float64
#  7   so2     23504 non-null  float64
#  8   pm2_5   23504 non-null  float64
#  9   pm10    23504 non-null  float64
#  10  nh3     23504 non-null  float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 2.0+ MB

# %% [markdown]
# CHECKING THE DUPLICATES

# %%
# checking for duplicates
df.duplicated().sum() # no duplicates found
# Out:
# 0

# %% [markdown]
# ERADICTION OF DUPLICATES

# %%
#Eradication of duplicate values 
df.drop_duplicates(inplace=True)

# %% [markdown]
# CHECKING THE NULL VALUES

# %%
#checking for any null values 
df.isnull().sum() #no null values
# Out:
# city     0
# date     0
# aqi      0
# co       0
# no       0
# no2      0
# o3       0
# so2      0
# pm2_5    0
# pm10     0
# nh3      0
# dtype: int64

# %% [markdown]
# DROPNA FUCTION

# %%
df.dropna(inplace=True,axis=0)

# %% [markdown]
# FETCHING THE DF

# %%
df
# Out:
#                 city        date  aqi       co     no    no2      o3    so2  \
# 0          Ahmedabad  30-11-2020    5   520.71   2.38  16.28  130.18  47.68
# 1          Ahmedabad  01-12-2020    5  1682.28   7.71  54.84    0.73  21.70
# 2          Ahmedabad  02-12-2020    5  1815.80  16.54  49.35    0.17  23.84
# 3          Ahmedabad  03-12-2020    5  2296.45  41.57  40.10    0.00  35.76
# 4          Ahmedabad  04-12-2020    5  2189.64  23.92  58.95    0.02  28.13
# ...              ...         ...  ...      ...    ...    ...     ...    ...
# 23499  Visakhapatnam  21-05-2023    3   353.81   0.00   2.08  100.14   4.11
# 23500  Visakhapatnam  22-05-2023    3   380.52   0.00   3.77   82.97   5.07
# 23501  Visakhapatnam  23-05-2023    3   390.53   0.00   4.28   80.11   5.19
# 23502  Visakhapatnam  24-05-2023    3   300.41   0.00   1.36   95.84   2.21
# 23503  Visakhapatnam  25-05-2023    4   427.25   0.00   6.00   88.69  10.73
#
#         pm2_5    pm10    nh3
# ...

# %% [markdown]
# VALUE COUNT ON CITY

# %%
df['city'].value_counts()
# Out:
# city
# Ahmedabad             904
# Aizawl                904
# Thiruvananthapuram    904
# Talcher               904
# Shillong              904
# Patna                 904
# Mumbai                904
# Lucknow               904
# Kolkata               904
# Kochi                 904
# Jorapokhar            904
# Jaipur                904
# Hyderabad             904
# Guwahati              904
# Gurugram              904
# Ernakulam             904
# Delhi                 904
# Coimbatore            904
# Chennai               904
# Chandigarh            904
# Brajrajnagar          904
# Bhopal                904
# Bengaluru             904
# Amritsar              904
# Amaravati             904
# Visakhapatnam         904
# Name: count, dtype: int64

# %% [markdown]
# FETCHING THE DELHI DATA

# %%
city_name='Delhi'
Delhi=df[df['city']=='Delhi']

# %% [markdown]
# SETING THE INDEX

# %%
Delhi.set_index('date',inplace=True)

# %% [markdown]
# FETCHING THE DELHI AQI DATA

# %%
aqi_series=Delhi['aqi']

# %% [markdown]
# FETCHING THE AQI SERIES

# %%
aqi_series
# Out:
# date
# 30-11-2020    5
# 01-12-2020    5
# 02-12-2020    5
# 03-12-2020    5
# 04-12-2020    5
#              ..
# 21-05-2023    5
# 22-05-2023    5
# 23-05-2023    4
# 24-05-2023    4
# 25-05-2023    5
# Name: aqi, Length: 904, dtype: int64

# %% [markdown]
# MAKING THE PLOT FOR DELHI

# %%
aqi_series.plot(figsize=(14, 7),color='salmon')
plt.title(f'AQI Levels Over Time for {city_name}')
plt.xlabel('Date')
plt.ylabel('AQI')
plt.show()

# %% [markdown]
# RESETING THE INDEX

# %%
Delhi.reset_index(drop=True,inplace=True)

# %%
Delhi
# Out:
#       city  aqi       co     no    no2      o3    so2   pm2_5    pm10    nh3
# 0    Delhi    5   988.01   1.24  13.71  205.99  34.33  133.73  156.15   9.88
# 1    Delhi    5  3150.94  30.40  66.49    0.00  14.90  299.99  428.61  16.09
# 2    Delhi    5  3524.78  18.11  71.97    0.05  12.16  455.67  571.47  10.64
# 3    Delhi    5  1922.61   0.03  52.78   27.54  11.09  208.94  266.25  10.13
# 4    Delhi    5  3738.40   0.64  78.14   11.00  16.69  595.27  748.71  10.26
# ..     ...  ...      ...    ...    ...     ...    ...     ...     ...    ...
# 899  Delhi    5  3070.83  12.85  81.57    0.08  69.62  172.37  327.52  66.88
# 900  Delhi    5  1575.47   0.32  50.04    9.92  31.95   81.03  186.17  23.31
# 901  Delhi    4  1068.12   0.00  34.62   37.19  23.60   65.72  160.28  23.56
# 902  Delhi    4  1001.36   0.01  37.01   27.18  24.08   53.07  136.26  24.32
# 903  Delhi    5  1161.58   0.00  24.33   62.94  28.85   82.46  108.60   8.87
#
# [904 rows x 10 columns]

# %% [markdown]
# FILTERING THE 2020 DELHI DATA

# %%
Delhi_2020=Delhi.loc[0:31] #AQI for Delhi in 2020

# %% [markdown]
# FILTERING THE 2021 DELHI DATA

# %%
Delhi_2021=Delhi.loc[32:396] #AQI for Delhi in 2021

# %% [markdown]
# FILTERING THE 2022 DELHI DATA

# %%
Delhi_2022=Delhi.loc[396:759] #AQI for Delhi in 2022

# %% [markdown]
# FILTERING THE 2023 DELHI DATA

# %%
Delhi_2023=Delhi.loc[759:] #AQI for Delhi in 2023

# %% [markdown]
# HISTOGRAM

# %%
df.hist(bins=10,figsize=(21,21),xrot=90.0,color='seagreen',ec='k')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# PIEPLOT

# %%
years_data = {
    2020: Delhi_2020,
    2021: Delhi_2021,
    2022: Delhi_2022,
    2023: Delhi_2023
}

# Create a figure with 4 subplots (2x2 grid)
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Plot each pie chart in its subplot
for i, (year, data) in enumerate(years_data.items()):
    x = list(data['aqi'].value_counts().values)
    label = list(data['aqi'].value_counts().keys())
    
    ax = axs[i // 2, i % 2]  # Determine the position of the subplot
    ax.pie(x, labels=label, autopct='%1.2f%%', wedgeprops={'ec':'k'}, shadow=True)
    ax.set_title(f"AQI Distribution for Delhi in {year}")

# Adjust layout
plt.tight_layout()
plt.show()

# %%
Delhi_aqi=Delhi[Delhi['aqi']==5] #to see which factor affects aqi the most

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 6))

# Plot AQI vs CO in the first subplot
sns.scatterplot(x='aqi', y='co', data=Delhi, color=sns.color_palette('BuGn_r', 1)[0], ax=axs[0])
axs[0].set_title('AQI vs CO')
axs[0].set_xlabel('AQI')
axs[0].set_ylabel('CO')

# Plot AQI vs NO in the second subplot
sns.scatterplot(x='aqi', y='no', data=Delhi, color=sns.color_palette('BuGn_r', 1)[0], ax=axs[1])
axs[1].set_title('AQI vs NO')
axs[1].set_xlabel('AQI')
axs[1].set_ylabel('NO')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# GROUPH THE CITY

# %%
city=df.groupby('city')

# %% [markdown]
# FETCHING THE JAIPUR DATA

# %%
Jaipur=city.get_group('Jaipur')

# %% [markdown]
# CATPLOT FOR CITY

# %%
sns.catplot(x='city',y='aqi',data=df,kind='bar',height=8.27,aspect=25.7/14.27,color='yellow',ec='k')
plt.xticks(rotation=90)
plt.xlabel('CITY')
plt.ylabel('AQI')
plt.show()

# %% [markdown]
# CATPLOT FOR O3

# %%
sns.catplot(x='aqi',y='o3',data=df,kind='bar',color='green')
plt.show()

# %% [markdown]
# RELPLOT

# %%
sns.relplot(x='pm2_5',y='pm10',data=df,hue='co')# positive realtion between x(pm2_5) and y(pm10)
plt.show()

# %% [markdown]
# SCATTERPLOT

# %%
# Create a figure with 3 subplots (1x3 grid)
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot CO vs NO in the first subplot
sns.scatterplot(x='co', y='no', data=df, color='violet', ax=axs[0])
axs[0].set_title('CO vs NO')
axs[0].set_xlabel('CO')
axs[0].set_ylabel('NO')

# Plot SO2 vs NO in the second subplot
sns.scatterplot(x='so2', y='no', data=df, color='purple', ax=axs[1])
axs[1].set_title('SO2 vs NO')
axs[1].set_xlabel('SO2')
axs[1].set_ylabel('NO')

# Plot O3 vs NO2 in the third subplot
sns.scatterplot(x='o3', y='no2', data=df, color='silver', ax=axs[2])
axs[2].set_title('O3 vs NO2')
axs[2].set_xlabel('O3')
axs[2].set_ylabel('NO2')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# CATPLOT FOR CITY

# %%
# Create the first subplot
ax1 = fig.add_subplot(3, 2, 1)
sns.catplot(x='city', y='o3', data=df, kind='strip', height=8.27,aspect=25.7/14.27, color='crimson', ax=ax1)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=120)
ax1.set_title('O3 by City')

# Create the second subplot
ax2 = fig.add_subplot(3, 2, 2)
sns.catplot(x='city', y='so2', data=df, kind='strip',height=8.27,aspect=25.7/14.27, color='fuchsia', ax=ax2)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=120)
ax2.set_title('SO2 by City')

# Create the third subplot
ax3 = fig.add_subplot(3, 2, 3)
sns.catplot(x='city', y='co', data=df, kind='strip',height=8.27,aspect=25.7/14.27, color='maroon', ax=ax3)
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=90)
ax3.set_title('CO by City')

# Create the fourth subplot
ax4 = fig.add_subplot(3, 2, 4)
sns.catplot(x='city', y='no', data=df, kind='strip',height=8.27,aspect=25.7/14.27, color='orchid', ax=ax4)
ax4.set_xticklabels(ax4.get_xticklabels(), rotation=90)
ax4.set_title('NO by City')

# Create the fifth subplot
ax5 = fig.add_subplot(3, 2, 5)
sns.catplot(x='city', y='no2', data=df, kind='strip',height=8.27,aspect=25.7/14.27, color='indigo', ax=ax5)
ax5.set_xticklabels(ax5.get_xticklabels(), rotation=90)
ax5.set_title('NO2 by City')

plt.show()

# %%
# Create a figure with 6 subplots (3x2 grid)
fig, axs = plt.subplots(3, 2, figsize=(20, 30))

# Plot O3 by city
sns.boxplot(x='city', y='o3', data=df, color='crimson', ax=axs[0, 0])
axs[0, 0].set_xticklabels(axs[0, 0].get_xticklabels(), rotation=90)
axs[0, 0].set_title('O3 by City')

# Plot SO2 by city
sns.boxplot(x='city', y='so2', data=df, color='fuchsia', ax=axs[0, 1])
axs[0, 1].set_xticklabels(axs[0, 1].get_xticklabels(), rotation=90)
axs[0, 1].set_title('SO2 by City')

# Plot CO by city (box plot)
sns.boxplot(x='city', y='nh3', data=df, color='turquoise', ax=axs[1, 0])
axs[1, 0].set_title('CITY V/S NH3')
axs[1, 0].set_xticklabels(axs[1, 0].get_xticklabels(), rotation=22)  # Maximum CO in Kolkata

# Plot CO by city
sns.boxplot(x='city', y='co', data=df, color='maroon', ax=axs[1, 1])
axs[1, 1].set_xticklabels(axs[1, 1].get_xticklabels(), rotation=90)
axs[1, 1].set_title('CO by City')

# Plot NO by city
sns.boxplot(x='city', y='no', data=df, color='orchid', ax=axs[2, 0])
axs[2, 0].set_xticklabels(axs[2, 0].get_xticklabels(), rotation=90)
axs[2, 0].set_title('NO by City')

# Plot NO2 by city
sns.boxplot(x='city', y='no2', data=df, color='indigo', ax=axs[2, 1])
axs[2, 1].set_xticklabels(axs[2, 1].get_xticklabels(), rotation=90)
axs[2, 1].set_title('NO2 by City')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# LENGTH OF THE CITY

# %%
city_list=['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru', 'Bhopal',
       'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore', 'Delhi',
       'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad', 'Jaipur',
       'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai', 'Patna',
       'Shillong', 'Talcher', 'Thiruvananthapuram', 'Visakhapatnam']
dt={}
for i in range(0,len(city_list)):
    dt[city_list[i]]=i+1

# %% [markdown]
# MAP

# %%
df['city']=df['city'].map(dt)

# %%
dt
# Out:
# {'Ahmedabad': 1,
#  'Aizawl': 2,
#  'Amaravati': 3,
#  'Amritsar': 4,
#  'Bengaluru': 5,
#  'Bhopal': 6,
#  'Brajrajnagar': 7,
#  'Chandigarh': 8,
#  'Chennai': 9,
#  'Coimbatore': 10,
#  'Delhi': 11,
#  'Ernakulam': 12,
#  'Gurugram': 13,
#  'Guwahati': 14,
#  'Hyderabad': 15,
#  'Jaipur': 16,
#  'Jorapokhar': 17,
#  'Kochi': 18,
#  'Kolkata': 19,
#  'Lucknow': 20,
#  'Mumbai': 21,
#  'Patna': 22,
#  'Shillong': 23,
#  'Talcher': 24,
#  'Thiruvananthapuram': 25,
#  'Visakhapatnam': 26}

# %% [markdown]
# MAKING A LIST

# %%
ls=list(df['date'])
df_date={}
for i in range(len(ls)):
    if ls[i].endswith('2020'):
         df_date[ls[i]]=2020
    elif ls[i].endswith('2021'):
         df_date[ls[i]]=2021
    elif ls[i].endswith('2022'):
         df_date[ls[i]]=2022
    elif ls[i].endswith('2023'):
         df_date[ls[i]]=2023

# %% [markdown]
# MAPPING THE LIST

# %%
df['date']=df['date'].map(df_date)

# %% [markdown]
# HEATMAP

# %%
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# GIVING THE AQI VALUES AS 5

# %%
df[df['aqi']==5]
# Out:
#        city  date  aqi       co     no    no2      o3    so2   pm2_5    pm10  \
# 0         1  2020    5   520.71   2.38  16.28  130.18  47.68   65.96   72.13
# 1         1  2020    5  1682.28   7.71  54.84    0.73  21.70  120.95  154.53
# 2         1  2020    5  1815.80  16.54  49.35    0.17  23.84  133.47  172.63
# 3         1  2020    5  2296.45  41.57  40.10    0.00  35.76  150.37  202.15
# 4         1  2020    5  2189.64  23.92  58.95    0.02  28.13  160.79  205.80
# ...     ...   ...  ...      ...    ...    ...     ...    ...     ...     ...
# 23480    26  2023    5  1789.09  50.96  48.67    0.00  52.45  117.00  138.50
# 23481    26  2023    5  1762.39  51.86  35.64    0.00  83.92   84.18  101.08
# 23486    26  2023    5   620.84   0.00   7.80   73.67   8.23   96.47  105.59
# 23490    26  2023    5  1482.01  40.68  35.99    0.00  43.39   78.81   99.51
# 23494    26  2023    5   614.17   0.00   9.51   67.95   6.02   83.70  126.52
#
#          nh3
# 0       8.36
# 1      27.36
# ...

# %% [markdown]
# VALUE COUNT ON AQI

# %%
df['aqi'].value_counts()
# Out:
# aqi
# 5    12458
# 4     4324
# 1     2618
# 2     2372
# 3     1732
# Name: count, dtype: int64

# %% [markdown]
# GIVING THE VALUES

# %%
aqi_5=df[df['aqi']==5]
aqi_4=df[df['aqi']==4]
aqi_3=df[df['aqi']==3]
aqi_2=df[df['aqi']==2]
aqi_1=df[df['aqi']==1]

# %% [markdown]
# TAKING 6000 SAMPLE

# %%
aqi_5=aqi_5.sample(6000)

# %% [markdown]
# CONCATINATION OF THE AQI

# %%
final_df=pd.concat([aqi_5,aqi_1,aqi_2,aqi_3,aqi_4],axis=0)

# %% [markdown]
# VALUE COUNT ON AQI

# %%
final_df['aqi'].value_counts()
# Out:
# aqi
# 5    6000
# 4    4324
# 1    2618
# 2    2372
# 3    1732
# Name: count, dtype: int64

# %% [markdown]
# SPILITING THE DATA INTO X AND Y

# %%
x=final_df.drop('aqi',axis=1)
y=final_df[['aqi']]

# %% [markdown]
# TRAIN THE DATA

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# SIZE IS 20-80

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# AS DFC

# %%
dfc=DecisionTreeClassifier()

# %% [markdown]
# TRAINING THE DATA

# %%
dfc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# SCORES

# %%
print('Training score:',dfc.score(x_train,y_train)*100)
print('Testing score:',dfc.score(x_test,y_test)*100)
# Out:
# Training score: 100.0
# Testing score: 99.20821114369501

# %% [markdown]
# MAKING THE PREDICTION

# %%
prediction=dfc.predict(x_test)

# %%
y_test['prediction']=prediction

# %% [markdown]
# CALCULATING THE PREDICTION

# %%
y_test.head(40)
# Out:
#        aqi  prediction
# 20516    2           2
# 5539     5           5
# 15497    3           3
# 1098     2           2
# 6583     5           5
# 15282    5           5
# 2709     3           3
# 20450    1           1
# 10405    5           5
# 22786    4           4
# 8449     1           1
# 4053     4           4
# 19396    5           5
# 9943     5           5
# 20579    2           2
# 8273     4           4
# 8235     3           3
# 12480    5           5
# 8332     1           1
# 12224    5           5
# 1927     5           5
# 14561    5           5
# 6036     4           4
# 8387     1           1
# 6765     5           5
# 11471    5           5
# 13536    2           2
# 18922    3           3
# 4447     4           4
# 14645    4           4
# 947      5           5
# 2031     2           2
# 6683     5           5
# 9812     5           5
# 7284     5           5
# 13965    4           4
# 2830     5           5
# 7440     4           4
# 4620     4           4
# ...

# %%
import joblib

# %% [markdown]
# SAVING THE decisisiontreeclassifier.lb

# %%
joblib.dump(dfc,'decisisiontreeclassifier.lb')
# Out:
# ['decisisiontreeclassifier.lb']

# %% [markdown]
# MAKING x AND y

# %%
x=final_df.drop('co',axis=1)
y=final_df[['co']]

# %% [markdown]
# IMPORTING THE SKLEARN MODEL

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# SIZE AS 20-80

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# DECISION TREE REGRESSOR

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# AS DFR

# %%
dfr=DecisionTreeRegressor()

# %% [markdown]
# FITING THE DATA

# %%
dfr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# CALCULATING THE SCORE

# %%
dfr.score(x_train,y_train)
# Out:
# 1.0

# %% [markdown]
# MAKING THE PREDICTION

# %%
prediction=dfr.predict(x_test)

# %% [markdown]
# CALCULATING THE PREDICTION

# %%
y_test['prediction']=prediction

# %%
y_test.head(40)
# Out:
#             co  prediction
# 7404    707.63      720.98
# 759     854.49      988.01
# 816     700.95      741.00
# 19987   407.22      393.87
# 6311    594.14      607.49
# 13273   220.30      290.39
# 9845   1028.06     1295.09
# 17394   814.44      934.60
# 1482    260.35      240.33
# 23111   201.94      226.97
# 19841   587.46      714.30
# 4305   1201.63      847.82
# 12907   297.07      303.75
# 23447   330.45      233.65
# 21451   720.98      453.95
# 14225  1174.93     1201.63
# 18092  1148.22     1094.82
# 10620   333.79      403.88
# 8835    473.98      600.82
# 22722   383.85      427.25
# 13022  1642.23     1735.69
# 1277    303.75      313.76
# 2001    253.68      267.03
# 16620  3898.62     3631.59
# 21351   370.50      407.22
# 6286    667.57      741.01
# 4179    587.46      574.11
# 15514   327.11      327.11
# 20501   774.38      560.76
# 12633   907.90      787.73
# 21823   440.60      614.17
# 1403    343.80      333.79
# 17700   781.06      540.73
# ...

# %% [markdown]
# SAVING THE DATA IN decisisiontreeregressor.lb

# %%
joblib.dump(dfr,'decisisiontreeregressor.lb')
# Out:
# ['decisisiontreeregressor.lb']
