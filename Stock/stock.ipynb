# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("stock_data.csv")
df
# Out:
#             Date     RELIANCE          TCS     HDFCBANK    ICICIBANK  \
# 0     1991-01-02          NaN          NaN          NaN          NaN
# 1     1991-01-03          NaN          NaN          NaN          NaN
# 2     1991-01-04          NaN          NaN          NaN          NaN
# 3     1991-01-07          NaN          NaN          NaN          NaN
# 4     1991-01-08          NaN          NaN          NaN          NaN
# ...          ...          ...          ...          ...          ...
# 8465  2024-07-01  3120.300049  3978.199951  1705.199951  1211.849976
# 8466  2024-07-02  3130.350098  4017.399902  1730.599976  1190.599976
# 8467  2024-07-03  3104.850098  3965.250000  1768.650024  1201.599976
# 8468  2024-07-04  3108.050049  4020.949951  1727.150024  1233.000000
# 8469  2024-07-05  3177.250000  4011.800049  1648.099976  1233.400024
#
#        BHARTIARTL        SBIN         INFY         LICI         ITC  ...  \
# ...

# %%
df1=df["Date"]
df1
# Out:
# 0       1991-01-02
# 1       1991-01-03
# 2       1991-01-04
# 3       1991-01-07
# 4       1991-01-08
#            ...
# 8465    2024-07-01
# 8466    2024-07-02
# 8467    2024-07-03
# 8468    2024-07-04
# 8469    2024-07-05
# Name: Date, Length: 8470, dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
filtered_df = df[(df['Date'] >= '2020-01-01') & (df['Date'] <= '2024-07-05')]

# %%
filtered_df
# Out:
#            Date     RELIANCE          TCS     HDFCBANK    ICICIBANK  \
# 7353 2020-01-01  1380.276611  2167.600098  1278.599976   536.750000
# 7354 2020-01-02  1403.775024  2157.649902  1286.750000   540.599976
# 7355 2020-01-03  1405.466553  2200.649902  1268.400024   538.849976
# 7356 2020-01-06  1372.870605  2200.449951  1240.949951   525.700012
# 7357 2020-01-07  1393.991699  2205.850098  1260.599976   522.900024
# ...         ...          ...          ...          ...          ...
# 8465 2024-07-01  3120.300049  3978.199951  1705.199951  1211.849976
# 8466 2024-07-02  3130.350098  4017.399902  1730.599976  1190.599976
# 8467 2024-07-03  3104.850098  3965.250000  1768.650024  1201.599976
# 8468 2024-07-04  3108.050049  4020.949951  1727.150024  1233.000000
# 8469 2024-07-05  3177.250000  4011.800049  1648.099976  1233.400024
#
#        BHARTIARTL        SBIN         INFY         LICI         ITC  ...  \
# 7353   444.946136  334.450012   736.849976          NaN  238.100006  ...
# ...

# %%
transposed_df = filtered_df.transpose()

# %%
={"email_message":x,"label":y}
email_data=pd.DataFrame(dt)
email_data.head()

# %%
transposed_df.reset_index(drop=True,inplace=True)

# %%
transposed_df
# Out:
#                            7353                 7354                 7355  \
# Date        2020-01-01 00:00:00  2020-01-02 00:00:00  2020-01-03 00:00:00
# RELIANCE            1380.276611          1403.775024          1405.466553
# TCS                 2167.600098          2157.649902          2200.649902
# HDFCBANK            1278.599976              1286.75          1268.400024
# ICICIBANK                536.75           540.599976           538.849976
# ...                         ...                  ...                  ...
# VIKASECO               1.905344             1.874109             1.811639
# ORIENTBELL               130.75           133.100006               135.75
# DONEAR                     30.1            32.200001            30.950001
# CAREERP              108.300003           111.800003                113.5
# SHREEPUSHK           104.150002                107.5           104.300003
#
#                            7356                 7357                 7358  \
# ...

# %%
filtered_df.dropna(axis=1,inplace=True)
# Out:
# C:\Users\Pragati\AppData\Local\Temp\ipykernel_13684\3625111044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.dropna(axis=1,inplace=True)

# %%
filtered_df.isnull().sum()
# Out:
# Date          0
# RELIANCE      0
# TCS           0
# HDFCBANK      0
# ICICIBANK     0
#              ..
# VIKASECO      0
# ORIENTBELL    0
# DONEAR        0
# CAREERP       0
# SHREEPUSHK    0
# Length: 1055, dtype: int64

# %%
filtered_df
# Out:
#            Date     RELIANCE          TCS     HDFCBANK    ICICIBANK  \
# 7353 2020-01-01  1380.276611  2167.600098  1278.599976   536.750000
# 7354 2020-01-02  1403.775024  2157.649902  1286.750000   540.599976
# 7355 2020-01-03  1405.466553  2200.649902  1268.400024   538.849976
# 7356 2020-01-06  1372.870605  2200.449951  1240.949951   525.700012
# 7357 2020-01-07  1393.991699  2205.850098  1260.599976   522.900024
# ...         ...          ...          ...          ...          ...
# 8465 2024-07-01  3120.300049  3978.199951  1705.199951  1211.849976
# 8466 2024-07-02  3130.350098  4017.399902  1730.599976  1190.599976
# 8467 2024-07-03  3104.850098  3965.250000  1768.650024  1201.599976
# 8468 2024-07-04  3108.050049  4020.949951  1727.150024  1233.000000
# 8469 2024-07-05  3177.250000  4011.800049  1648.099976  1233.400024
#
#        BHARTIARTL        SBIN         INFY         ITC   HINDUNILVR  ...  \
# 7353   444.946136  334.450012   736.849976  238.100006  1936.550049  ...
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Step 1: Filter the data and calculate rolling average

# %%
filtered_df['Date'] = pd.to_datetime(filtered_df['Date'])
filtered_df = filtered_df[(filtered_df['Date'] >= '2020-01-01')]
rolling_avg = filtered_df.drop('Date', axis=1).rolling(window=10).mean()
# Out:
# C:\Users\Pragati\AppData\Local\Temp\ipykernel_13684\2039335117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Date'] = pd.to_datetime(filtered_df['Date'])

# %%
# Step 2: Feature Engineering
features = pd.concat([filtered_df.drop('Date', axis=1), rolling_avg.shift(1)], axis=1)
labels = ((filtered_df.drop('Date', axis=1) > filtered_df.drop('Date', axis=1).shift(1)) & 
          (filtered_df.drop('Date', axis=1) > rolling_avg.shift(1)))

# %%
features
# Out:
#          RELIANCE          TCS     HDFCBANK    ICICIBANK   BHARTIARTL  \
# 7353  1380.276611  2167.600098  1278.599976   536.750000   444.946136
# 7354  1403.775024  2157.649902  1286.750000   540.599976   446.811127
# 7355  1405.466553  2200.649902  1268.400024   538.849976   446.712952
# 7356  1372.870605  2200.449951  1240.949951   525.700012   441.363403
# 7357  1393.991699  2205.850098  1260.599976   522.900024   436.897247
# ...           ...          ...          ...          ...          ...
# 8465  3120.300049  3978.199951  1705.199951  1211.849976  1454.000000
# 8466  3130.350098  4017.399902  1730.599976  1190.599976  1418.949951
# 8467  3104.850098  3965.250000  1768.650024  1201.599976  1419.849976
# 8468  3108.050049  4020.949951  1727.150024  1233.000000  1423.050049
# 8469  3177.250000  4011.800049  1648.099976  1233.400024  1429.699951
#
#             SBIN         INFY         ITC   HINDUNILVR           LT  ...  \
# ...

# %%
for i in range(len(filtered_data)):
    filtered_data[""][i]=r
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13684\3233919777.py in ?()
# ----> 1 if labels==True:
#       2     print("1")
#       3 else:
#       4     print("0")
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Step 3: Model Training
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[117], line 4
#       2 X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)
#       3 model = RandomForestClassifier()
# ----> 4 model.fit(X_train, y_train)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\ensemble\_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
# ...

# %%
# Step 4: Model Prediction
predictions = model.predict(X_test)

# %%
# Step 5: Output
predicted_data = filtered_df.loc[y_test.index]
predicted_data['Predicted'] = predictions
print(predicted_data)

# %%
X = filtered_df['Date']
y = filtered_df.drop(['Date'], axis=1)
rolling_avg = y.rolling(window=10).mean()
previous_day=filtered_df.shift(1)
above_previous_day = y > previous_day
above_10_day_avg = y > rolling_avg
selected_data = df[(above_previous_day & above_10_day_avg).all(axis=1)]
print(selected_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13684\2619464374.py in ?()
#       1 X = filtered_df['Date']
#       2 y = filtered_df.drop(['Date'], axis=1)
#       3 rolling_avg = y.rolling(window=10).mean()
#       4 previous_day=filtered_df.shift(1)
# ----> 5 above_previous_day = y > previous_day
#       6 above_10_day_avg = y > rolling_avg
#       7 selected_data = df[(above_previous_day & above_10_day_avg).all(axis=1)]
#       8 print(selected_data)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py in ?(self, other)
# ...

# %%
from datetime import datetime, timedelta

# %%
x = filtered_df['Date']
y = filtered_df.drop('Date', axis=1)

# %%
x.shape
# Out:
# (1117,)

# %%
y.shape
# Out:
# (1117, 1054)

# %%
df['last_10_days_avg'] = df['y'].rolling(window=10).mean()
filtered_data = df[(df['last_10_days_avg'] > df['today_price']) & (df['last_10_days_avg'] > df['previous_day_price'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df['last_10_days_avg'] = df['y'].rolling(window=10).mean()
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
user_input = input("Enter today's date (YYYY-MM-DD): ")
today = datetime.strptime(user_input, '%Y-%m-%d')
previous_date = today - timedelta(days=1)
start_date = today - timedelta(days=10)
filtered_df = df[(df['Date'] >= previous_date) & (df['Date'] <= today)]
last_10_days_df = df[(df['Date'] > start_date) & (df['Date'] <= today)]
average_prices = last_10_days_df.groupby('y')['price'].mean()
print(average_prices)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 8
#       6 filtered_df = df[(df['Date'] >= previous_date) & (df['Date'] <= today)]
#       7 last_10_days_df = df[(df['Date'] > start_date) & (df['Date'] <= today)]
# ----> 8 average_prices = last_10_days_df.groupby('y')['price'].mean()
#       9 print(average_prices)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
# ...

# %%
filtered_df
# Out:
#            Date     RELIANCE          TCS     HDFCBANK    ICICIBANK  \
# 7353 2020-01-01  1380.276611  2167.600098  1278.599976   536.750000
# 7354 2020-01-02  1403.775024  2157.649902  1286.750000   540.599976
# 7355 2020-01-03  1405.466553  2200.649902  1268.400024   538.849976
# 7356 2020-01-06  1372.870605  2200.449951  1240.949951   525.700012
# 7357 2020-01-07  1393.991699  2205.850098  1260.599976   522.900024
# ...         ...          ...          ...          ...          ...
# 8465 2024-07-01  3120.300049  3978.199951  1705.199951  1211.849976
# 8466 2024-07-02  3130.350098  4017.399902  1730.599976  1190.599976
# 8467 2024-07-03  3104.850098  3965.250000  1768.650024  1201.599976
# 8468 2024-07-04  3108.050049  4020.949951  1727.150024  1233.000000
# 8469 2024-07-05  3177.250000  4011.800049  1648.099976  1233.400024
#
#        BHARTIARTL        SBIN         INFY         LICI         ITC  ...  \
# 7353   444.946136  334.450012   736.849976          NaN  238.100006  ...
# ...
